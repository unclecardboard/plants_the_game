# %% [markdown]
# # Plant Tinder APK Builder
# This notebook builds your Android APK using Google Colab.
#
# **Steps:**
# 1. Click Runtime > Run All
# 2. Wait ~30 minutes
# 3. Download the APK from the Files panel on the left
#
# ---

# %%
# Install system dependencies
# !apt-get update -qq
# !apt-get install -y openjdk-11-jdk wget unzip
print("✅ System dependencies installed")

# %%
# Install Buildozer
# !pip install -q buildozer cython==0.29.36
print("✅ Buildozer installed")

# %%
# Clone your repository
# !git clone https://github.com/unclecardboard/plants_the_game.git
# %cd plants_the_game
print("✅ Repository cloned")

# %%
# Build the APK (this takes ~30 minutes)
# !yes | buildozer -v android debug
print("\n\n✅ APK BUILD COMPLETE!")
print("📱 Find your APK in the 'bin' folder")
print("👈 Use the Files panel on the left to download it")

# %%
# List the APK files
# !ls -lh bin/*.apk
print("\n📥 Right-click the APK file above to download it")
